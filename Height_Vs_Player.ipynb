# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# players_21 data files
players_data_path = "data/players_21.csv"

# %%
# Read the players data
df = pd.read_csv(players_data_path)

# %%
# Display the data table for preview
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05
# 2           J. Oblak                            Jan Oblak   27  1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31  1988-08-21
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  1992-02-05
#
#    height_cm  weight_kg nationality            club_name  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  66+3  65+3
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        188         87    Slovenia      Atlético Madrid  ...  32+3  36+3
# 3        184         80      Poland    FC Bayern München  ...  64+3  65+3
# 4        175         68      Brazil  Paris Saint-Germain  ...  67+3  62+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  65+3  65+3  66+3  62+3  52+3  52+3  52+3  62+3
# 1  61+3  61+3  65+3  61+3  54+3  54+3  54+3  61+3
# 2  36+3  36+3  32+3  32+3  33+3  33+3  33+3  32+3
# 3  65+3  65+3  64+3  61+3  60+3  60+3  60+3  61+3
# 4  62+3  62+3  67+3  62+3  49+3  49+3  49+3  62+3
#
# [5 rows x 106 columns]

# %%
import matplotlib.pyplot as plt

# %%
shoert_name = ['L. Messi', 'Cristiano Ronaldo', 'J. Oblak', 'R. Lewandowski', 'Neymar Jr', 'K. De Bruyne', 'K. MbappÃ©', 'M. ter Stegen', 'V. van Dijk', 
'Alisson', 'S. ManÃ©', 'M. Salah', 'T. Courtois', 'S. AgÃ¼ero'
]
height_cm = [170, 187, 188, 184, 175, 181, 178, 187, 193, 191, 175, 175, 199, 173]

# %%
plt.bar(shoert_name, height_cm, color='skyblue', edgecolor='black')
plt.xlabel('Names')
plt.ylabel('Heights (cm)')
plt.title('Heights of Different Individuals')
plt.show()# Slant the y-axis label
plt.gca().yaxis.label.set_rotation(50) 
# Adjust the rotation angle as needed

# %%
import matplotlib.pyplot as plt

# %%
# !pip install import_ipynb
# Out:
# Requirement already satisfied: import_ipynb in c:\users\endal\anaconda3\lib\site-packages (0.1.4)
# Requirement already satisfied: IPython in c:\users\endal\anaconda3\lib\site-packages (from import_ipynb) (8.25.0)
# Requirement already satisfied: nbformat in c:\users\endal\anaconda3\lib\site-packages (from import_ipynb) (5.9.2)
# Requirement already satisfied: decorator in c:\users\endal\anaconda3\lib\site-packages (from IPython->import_ipynb) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\endal\anaconda3\lib\site-packages (from IPython->import_ipynb) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\endal\anaconda3\lib\site-packages (from IPython->import_ipynb) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\endal\anaconda3\lib\site-packages (from IPython->import_ipynb) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\endal\anaconda3\lib\site-packages (from IPython->import_ipynb) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\endal\anaconda3\lib\site-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\endal\anaconda3\lib\site-packages (from IPython->import_ipynb) (5.14.3)
# Requirement already satisfied: colorama in c:\users\endal\anaconda3\lib\site-packages (from IPython->import_ipynb) (0.4.6)
# Requirement already satisfied: fastjsonschema in c:\users\endal\anaconda3\lib\site-packages (from nbformat->import_ipynb) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\endal\anaconda3\lib\site-packages (from nbformat->import_ipynb) (4.19.2)
# Requirement already satisfied: jupyter-core in c:\users\endal\anaconda3\lib\site-packages (from nbformat->import_ipynb) (5.7.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\endal\anaconda3\lib\site-packages (from jedi>=0.16->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\endal\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\endal\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\endal\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\endal\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.10.6)
# Requirement already satisfied: wcwidth in c:\users\endal\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython->import_ipynb) (0.2.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\endal\anaconda3\lib\site-packages (from jupyter-core->nbformat->import_ipynb) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\endal\anaconda3\lib\site-packages (from jupyter-core->nbformat->import_ipynb) (305.1)
# Requirement already satisfied: executing in c:\users\endal\anaconda3\lib\site-packages (from stack-data->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\endal\anaconda3\lib\site-packages (from stack-data->IPython->import_ipynb) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\endal\anaconda3\lib\site-packages (from stack-data->IPython->import_ipynb) (0.2.2)
# Requirement already satisfied: six in c:\users\endal\anaconda3\lib\site-packages (from asttokens->stack-data->IPython->import_ipynb) (1.16.0)

# %%
import import_ipynb

# %%
import pandas as pd

# %%
players_data_path = "data/players_21.csv"

# %%
df = pd.read_csv(players_data_path)

# %%
print(df.head())
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     200389  https://sofifa.com/player/200389/jan-oblak/210002
# 3     188545  https://sofifa.com/player/188545/robert-lewand...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   33  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05
# 2           J. Oblak                            Jan Oblak   27  1993-01-07
# 3     R. Lewandowski                   Robert Lewandowski   31  1988-08-21
# 4          Neymar Jr        Neymar da Silva Santos Júnior   28  1992-02-05
#
#    height_cm  weight_kg nationality            club_name  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  66+3  65+3
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        188         87    Slovenia      Atlético Madrid  ...  32+3  36+3
# 3        184         80      Poland    FC Bayern München  ...  64+3  65+3
# 4        175         68      Brazil  Paris Saint-Germain  ...  67+3  62+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  65+3  65+3  66+3  62+3  52+3  52+3  52+3  62+3
# 1  61+3  61+3  65+3  61+3  54+3  54+3  54+3  61+3
# 2  36+3  36+3  32+3  32+3  33+3  33+3  33+3  32+3
# 3  65+3  65+3  64+3  61+3  60+3  60+3  60+3  61+3
# 4  62+3  62+3  67+3  62+3  49+3  49+3  49+3  62+3
#
# [5 rows x 106 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
players_data_path = "players_21.csv"

# %% [markdown]
# # Read specific columns from the CSV file
# df = pd.read_csv('players_data_path', usecols=['Column3', 'Column7', 'Column13])
# print(df)

# %%
data = {
    'Height': [170, 187, 188, 184, 175, 181, 178, 187, 193, 191, 175, 175, 199, 173, 184],
    'Overall_performance': [93, 92, 91, 91, 91, 90, 90, 90, 90, 90, 90, 90, 89, 89, 89]
}
df = pd.DataFrame(data)

# Create a scatter plot
df.plot.scatter(x='Height', y='Overall_performance')

# Show the plot
plt.show()

# %%
data = {
    'Height': [170, 187, 188, 184, 175, 181, 178, 187, 193, 191, 175, 175, 199, 173, 184],
    'Overall_performance': [93, 92, 91, 91, 91, 90, 90, 90, 90, 90, 90, 90, 89, 89, 89]
}
df = pd.DataFrame(data)

# Create a scatter plot
df.plot.scatter(x='Height', y='Overall_performance')

# Show the plot
plt.show()

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
# Data
data = {
    'Height': [170, 187, 188, 184, 175, 181, 178, 187, 193, 191, 175, 175, 199, 173, 184],
    'Overall_performance': [93, 92, 91, 91, 91, 90, 90, 90, 90, 90, 90, 90, 89, 89, 89]
}

# %%
# Convert data to numpy arrays for easier handling
heights = np.array(data['Height'])
performance = np.array(data['Overall_performance'])

# %%
# Create scatter plot
plt.scatter(heights, performance, c=performance, cmap='viridis', s=100, alpha=0.7, edgecolors='w')

# %%
# Add labels and title
plt.xlabel('Height (cm)')
plt.ylabel('Overall Performance')
plt.title('Scatter Plot of Height vs Overall Performance')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Height vs Overall Performance')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data = {
    'Height': [170, 187, 188, 184, 175, 181, 178, 187, 193, 191, 175, 175, 199, 173, 184],
    'Overall_performance': [93, 92, 91, 91, 91, 90, 90, 90, 90, 90, 90, 90, 89, 89, 89]
}

# Convert data to numpy arrays for easier handling
heights = np.array(data['Height'])
performance = np.array(data['Overall_performance'])

# Create scatter plot
plt.scatter(heights, performance, c=performance, cmap='viridis', s=100, alpha=0.7, edgecolors='w')

# Add color bar
cbar = plt.colorbar()
cbar.set_label('Overall Performance')

# Add labels and title
plt.xlabel('Height (cm)')
plt.ylabel('Overall Performance')
plt.title('Scatter Plot of Height vs Overall Performance')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
short_name = ['L. Messi', 'Cristiano Ronaldo', 'J. Oblak', 'R. Lewandowski', 'Neymar Jr', 'K. De Bruyne', 'K. Mbappé', 'M. ter Stegen', 'V. van Dijk', 
'Alisson', 'S. Mané', 'M. Salah', 'T. Courtois', 'S. Agüero']
height_cm = [170, 187, 188, 184, 175, 181, 178, 187, 193, 191, 175, 175, 199, 173]

# Create bar plot
plt.bar(short_name, height_cm, color='skyblue', edgecolor='black')

# Set labels and title
plt.xlabel('Names')
plt.ylabel('Heights (cm)')
plt.title('Heights of Different Individuals')

# Slant the y-axis label
plt.gca().xaxis.label.set_rotation(45)  # Adjust the rotation angle as needed

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
short_name = ['L. Messi', 'Cristiano Ronaldo', 'J. Oblak', 'R. Lewandowski', 'Neymar Jr', 'K. De Bruyne', 'K. Mbappé', 'M. ter Stegen', 'V. van Dijk', 
'Alisson', 'S. Mané', 'M. Salah', 'T. Courtois', 'S. Agüero']
height_cm = [170, 187, 188, 184, 175, 181, 178, 187, 193, 191, 175, 175, 199, 173]

# Create bar plot
plt.bar(short_name, height_cm, color='skyblue', edgecolor='black')

# Set labels and title
plt.xlabel('Names')
plt.ylabel('Heights (cm)')
plt.title('Heights of Different Individuals')

# Rotate x-axis labels
plt.xticks(rotation=45)

# Show plot
plt.show()
